# %% [markdown]
# # About notebook:
# * What I concretely have this far on using bokeh for interactive map
#
# Todo:
#
# * Add hover ("mouse hold over" that we can add information to)
# *  Implement "Africa geoplot shapefile" to enable visualization of statistics per country
#   * (e.g. like this example for Texas: http://bokeh.pydata.org/en/latest/docs/gallery/texas.html)
# * Dynamic slider?
# * Connecting plots?

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import datetime

# %matplotlib inline

# %% [markdown]
# ## Importing ACLED data

# %%
folder = 'data'
file = 'ACLED-Version-7-All-Africa-1997-2016_csv_dyadic-file.zip'

# %% [markdown]
# Importing using pd.read_csv (reading the csv directly from zip file)
#
# **Note:** Using
#
# * encoding='latin_1' because utf encoding resulted in error (non-utf characters in data)
# * low_memory=True due to warning of mixed data type in some columns (17,19,20)

# %%
df = pd.read_csv(folder+'/'+file, encoding='latin_1', low_memory=False)

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# ### Remove NA columns
# Remove columns with **no** data (there are 11 of them in the file):

# %%
df = df.dropna(axis=1, how='all')

# %% [markdown]
# ### Convert 'EVENT_DATE' to datetime

# %%
def datetime_dmy(datetimestring):
    # Returns datetime object from string on format dd/mm/yyyy
    return datetime.datetime.strptime(datetimestring,
                                      '%d/%m/%Y')

df['EVENT_DATE'] = df['EVENT_DATE'].apply(datetime_dmy)

# %%
# Checking that all went well
print(type(df['EVENT_DATE'][0]))
print(df['EVENT_DATE'][10])
# Out:
# <class 'pandas.tslib.Timestamp'>
# 1997-01-22 00:00:00

# %% [markdown]
# ### Changing LATITUDE and LONGITUDE to floats
# They are imported with dtype=object

# %%
print("dtype before: ", df['LATITUDE'].dtype)
df = df.astype({
    'LATITUDE': float, 'LONGITUDE': float})

print("dtype after:  ", df['LATITUDE'].dtype)
# Out:
# dtype before:  object
# dtype after:   float64

# %% [markdown]
# # Minor data exploration
# Inspired by Dirk's examples in lecture 13.02.

# %%
df_f = df[['EVENT_DATE', 'COUNTRY', 'FATALITIES']]

# %% [markdown]
# ## Plotting fatalities

# %% [markdown]
# ### Creating pivot table
# * Important to set 'aggfunc' to sum (standard is mean)

# %%
df_piv = df_f.pivot_table(index='EVENT_DATE',
                              columns='COUNTRY',
                              values='FATALITIES',
                              aggfunc=np.sum)

# %% [markdown]
# ### Resampling pivot to monthly

# %%
df_piv = df_piv.resample('1M').sum()

# %% [markdown]
# ### Extract countries
# Extract 5 countries with highest total fatalities (for plotting)

# %%
most_fat = list(df_piv.sum().sort_values(
                     ascending=False)[0:5].index)

# %%
print("Total number of events:")
df_piv.sum().sort_values(
                     ascending=False)[0:5]
# Out:
# Total number of events:
# COUNTRY
# Angola                          143743.0
# Sudan                            84710.0
# Eritrea                          79369.0
# Democratic Republic of Congo     75586.0
# Nigeria                          56737.0
# dtype: float64

# %%
df_fat = df_piv[most_fat]

# %%
ax = df_fat.plot(figsize=(10,8))
ax.set_ylabel("Fatalities")
ax.set_xlabel("Month")

# %% [markdown]
# ## Plotting using pandas
# Pandas is more flexible and allows zooming ++

# %%
# TO BE FIXED

# %% [markdown]
# # Bokeh geo-plotting
# Based on:
# http://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/blob/master/tutorial/11%20-%20geo.ipynb

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="da3fbcc9-2a83-440d-8b87-91a2105ebc2a">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure
from bokeh.tile_providers import WMTSTileSource

# NOTE: This is a little off Africa, but can easily be moved:
dist = 6000000
x_min = -30000
y_min = -8000000

Africa = x_range,y_range = ((-x_min,x_min+dist), (-y_min,y_min+dist))

fig = figure(tools='pan, wheel_zoom', x_range=x_range, y_range=y_range)
fig.axis.visible = False

# %%
url = 'http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png'
attribution = "Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL"

fig.add_tile(WMTSTileSource(url=url, attribution=attribution))
# Out:
# TileRenderer(id='980e7987-8530-4dec-a370-ac356c138355', ...)

# %%
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="91d49481-0686-4f12-949b-540c533ddff8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("91d49481-0686-4f12-949b-540c533ddff8").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("91d49481-0686-4f12-949b-540c533ddff8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '91d49481-0686-4f12-949b-540c533ddff8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c761ee1e-ac7a-48df-a391-a72fed817652":{"roots":{"references":[{"attributes":{},"id":"44bba345-0e62-4b75-b130-08abf51c8d9f","type":"BasicTickFormatter"},{"attributes":{"attribution":"Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL","url":"http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png"},"id":"0db593e8-2a38-495c-919d-b42f373ce90d","type":"WMTSTileSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1b2265a1-554b-4a07-80f6-26a51d49a200","type":"PanTool"},{"id":"dcc24c93-da25-4af0-9311-4983eaf7f637","type":"WheelZoomTool"}]},"id":"e84642b1-ccfe-40d2-b851-bfec5dadb39e","type":"Toolbar"},{"attributes":{"tile_source":{"id":"0db593e8-2a38-495c-919d-b42f373ce90d","type":"WMTSTileSource"}},"id":"980e7987-8530-4dec-a370-ac356c138355","type":"TileRenderer"},{"attributes":{"callback":null,"end":5970000,"start":30000},"id":"c5f643f1-0a32-43f5-9fcd-07a56496cb81","type":"Range1d"},{"attributes":{"plot":null,"text":""},"id":"60525d73-4523-462b-a7b9-e970b8299f36","type":"Title"},{"attributes":{"callback":null,"end":-2000000,"start":8000000},"id":"f701ef4f-bdec-4fa8-b78c-a58cacbf33a0","type":"Range1d"},{"attributes":{"formatter":{"id":"cbfc817d-ddae-4c5e-b24d-f6b85e90ac25","type":"BasicTickFormatter"},"plot":{"id":"fbae4e4e-bffe-443e-85cf-889fd8e516f5","subtype":"Figure","type":"Plot"},"ticker":{"id":"bcf383dd-f11c-4314-852b-d4d3f36f5eae","type":"BasicTicker"},"visible":false},"id":"ff0bd3b7-c49f-4e04-9208-419a42f2e393","type":"LinearAxis"},{"attributes":{},"id":"bcf383dd-f11c-4314-852b-d4d3f36f5eae","type":"BasicTicker"},{"attributes":{"plot":{"id":"fbae4e4e-bffe-443e-85cf-889fd8e516f5","subtype":"Figure","type":"Plot"},"ticker":{"id":"bcf383dd-f11c-4314-852b-d4d3f36f5eae","type":"BasicTicker"}},"id":"2e76a348-9590-447b-bbde-f005ae93359f","type":"Grid"},{"attributes":{"formatter":{"id":"44bba345-0e62-4b75-b130-08abf51c8d9f","type":"BasicTickFormatter"},"plot":{"id":"fbae4e4e-bffe-443e-85cf-889fd8e516f5","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad7c00f4-940e-4b40-bd4a-5a847669a301","type":"BasicTicker"},"visible":false},"id":"59e41f09-9f53-4018-9f6c-372713b8c14b","type":"LinearAxis"},{"attributes":{},"id":"ad7c00f4-940e-4b40-bd4a-5a847669a301","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"fbae4e4e-bffe-443e-85cf-889fd8e516f5","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad7c00f4-940e-4b40-bd4a-5a847669a301","type":"BasicTicker"}},"id":"1722f10c-6b54-4c15-8568-3fb0eed0eb8c","type":"Grid"},{"attributes":{"plot":{"id":"fbae4e4e-bffe-443e-85cf-889fd8e516f5","subtype":"Figure","type":"Plot"}},"id":"dcc24c93-da25-4af0-9311-4983eaf7f637","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"fbae4e4e-bffe-443e-85cf-889fd8e516f5","subtype":"Figure","type":"Plot"}},"id":"1b2265a1-554b-4a07-80f6-26a51d49a200","type":"PanTool"},{"attributes":{},"id":"cbfc817d-ddae-4c5e-b24d-f6b85e90ac25","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"ff0bd3b7-c49f-4e04-9208-419a42f2e393","type":"LinearAxis"}],"left":[{"id":"59e41f09-9f53-4018-9f6c-372713b8c14b","type":"LinearAxis"}],"renderers":[{"id":"ff0bd3b7-c49f-4e04-9208-419a42f2e393","type":"LinearAxis"},{"id":"2e76a348-9590-447b-bbde-f005ae93359f","type":"Grid"},{"id":"59e41f09-9f53-4018-9f6c-372713b8c14b","type":"LinearAxis"},{"id":"1722f10c-6b54-4c15-8568-3fb0eed0eb8c","type":"Grid"},{"id":"980e7987-8530-4dec-a370-ac356c138355","type":"TileRenderer"}],"title":{"id":"60525d73-4523-462b-a7b9-e970b8299f36","type":"Title"},"tool_events":{"id":"c3a06e10-8333-4b44-9cd0-d2ef021723cc","type":"ToolEvents"},"toolbar":{"id":"e84642b1-ccfe-40d2-b851-bfec5dadb39e","type":"Toolbar"},"x_range":{"id":"c5f643f1-0a32-43f5-9fcd-07a56496cb81","type":"Range1d"},"y_range":{"id":"f701ef4f-bdec-4fa8-b78c-a58cacbf33a0","type":"Range1d"}},"id":"fbae4e4e-bffe-443e-85cf-889fd8e516f5","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"c3a06e10-8333-4b44-9cd0-d2ef021723cc","type":"To ...
#             var render_items = [{"docid":"c761ee1e-ac7a-48df-a391-a72fed817652","elementid":"91d49481-0686-4f12-949b-540c533ddff8","modelid":"fbae4e4e-bffe-443e-85cf-889fd8e516f5"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {

# %% [markdown]
# ## Adding some points:

# %%
# Function comes from tutorial (see section header):
def wgs84_to_web_mercator(df, lon="LONGITUDE", lat="LATITUDE"):
    """Converts decimal longitude/latitude to Web Mercator format"""
    k = 6378137
    df["x"] = df[lon] * (k * np.pi/180.0)
    df["y"] = np.log(np.tan((90 + df[lat]) * np.pi/360.0)) * k
    return df

# %% [markdown]
# Selecting nor or less random samples (statistically speaking

# %%
N_points = 10000

test_points = df.iloc[0:N_points][['COUNTRY','LATITUDE', 'LONGITUDE', 'FATALITIES']]

# %%
wgs84_to_web_mercator(test_points)

None # To surpress output from function call

# %% [markdown]
# #### Plotting the points from above
# **Note**: Size of plot set proportional with fatalities, in a little dodgy way (for now)

# %%
fig.circle(x=test_points['x'], y=test_points['y'],fill_color='blue', size=4*np.log(1+test_points['FATALITIES']))
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bd94c4d2-1a40-4e16-9cc9-36aff570f257"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("bd94c4d2-1a40-4e16-9cc9-36aff570f257").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bd94c4d2-1a40-4e16-9cc9-36aff570f257");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bd94c4d2-1a40-4e16-9cc9-36aff570f257' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7eb5a0cd-5067-4128-8b73-0dea2aa226e1":{"roots":{"references":[{"attributes":{},"id":"44bba345-0e62-4b75-b130-08abf51c8d9f","type":"BasicTickFormatter"},{"attributes":{"attribution":"Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL","url":"http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png"},"id":